# %% [markdown]
# <a href="https://colab.research.google.com/github/Bishal2211/Simulation_and_Modeling_Lab/blob/main/Lab_Assignment01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simulation and Modeling Lab
#
# Course Code: CSE 413
#
# Name: Ismam Ahmed
#
# ID: 0432220005101116
#
# Sec: 7B2; Batch: 53
#
# Semester: Spring 2026
#
# Assignment No.: 01

# %% [markdown]
# Assignment Tasks
# Assignment 1: Basic Matrix Operations
#
# Create two 3×3 matrices with random integers in Python.
# Perform addition, subtraction, and multiplication operations on these matrices.
# Compute the determinant, inverse, and rank of one of the matrices.
#
# Assignment 2: Matrix Plotting and Visualization
#
# Generate and Plot Two Random Vectors:
#
# a. Create two vectors, each containing 15 random floats of your choice.
#
# b. Plot these vectors on the same graph using matplotlib to compare how they look.
#
# c. Label the axes appropriately and give the plot a title.

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Assignment 01**

# %%
import numpy as np

# Creating two random 3x3 matrices
matrix1 = np.random.randint(0, 10, size=(3, 3))
matrix2 = np.random.randint(0, 10, size=(3, 3))

# Matrix Addition
matrix_sum = matrix1 + matrix2

# Matrix Subtraction
matrix_diff = matrix1 - matrix2

# Matrix Multiplication
matrix_product = np.dot(matrix1, matrix2)

# Determinants
det1 = np.linalg.det(matrix1)
det2 = np.linalg.det(matrix2)

# Inverse of matrix1 (if possible)
if det1 != 0:
    inverse1 = np.linalg.inv(matrix1)
else:
    print("Matrix 1 is singular, inverse not possible")

# Inverse of matrix2 (if possible)
if det2 != 0:
    inverse2 = np.linalg.inv(matrix2)
else:
    print("Matrix 2 is singular, inverse not possible")

# Rank calculation
rank1 = np.linalg.matrix_rank(matrix1)
rank2 = np.linalg.matrix_rank(matrix2)

# Display results
print("Matrix 1:\n", matrix1, "\n")
print("Matrix 2:\n", matrix2, "\n")
print("Addition Result:\n", matrix_sum, "\n")
print("Subtraction Result:\n", matrix_diff, "\n")
print("Multiplication Result:\n", matrix_product, "\n")
print("Determinant of Matrix 1:", det1, "\n")
print("Determinant of Matrix 2:", det2, "\n")

if det1 != 0:
    print("Inverse of Matrix 1:\n", inverse1, "\n")

if det2 != 0:
    print("Inverse of Matrix 2:\n", inverse2, "\n")

print("Rank of Matrix 1:", rank1)
print("Rank of Matrix 2:", rank2)
# Out:
# Matrix A:
#  [[3 6 0]
#  [9 6 6]
#  [3 2 8]]
#
# Matrix B:
#  [[7 6 7]
#  [4 3 6]
#  [7 2 2]]
#
# Sum of Matrix:
#  [[10 12  7]
#  [13  9 12]
#  [10  4 10]]
#
# Subtraction of Matrix:
#  [[-4  0 -7]
#  [ 5  3  0]
#  [-4  0  6]]
#
# Multiplication of Matrix:
#  [[ 45  36  57]
#  [129  84 111]
#  [ 85  40  49]]
#
# Matrix Determinant of Mat A:
#  -216.00000000000006
#
# Matrix Determinant of Mat B:
#  71.0
#
# Matrix Inverse of Mat A:
#  [[-0.16666667  0.22222222 -0.16666667]
#  [ 0.25       -0.11111111  0.08333333]
#  [ 0.         -0.05555556  0.16666667]]
#
# Matrix Inverse of Mat B:
#  [[-0.08450704  0.02816901  0.21126761]
#  [ 0.47887324 -0.49295775 -0.1971831 ]
#  [-0.18309859  0.3943662  -0.04225352]]
#
# Matrix Rank of Mat A:
#  3
#
# Matrix Rank of Mat B:
#  3

# %% [markdown]
# # **Assignment 02**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two random vectors (15 float values each)
vector1 = np.random.uniform(0, 50, 15)
vector2 = np.random.uniform(0, 50, 15)

print("Vector 1:\n", vector1, "\n")
print("Vector 2:\n", vector2, "\n")

# Create index positions for x-axis
positions = np.arange(1, 16)

# Plot both vectors on the same graph
plt.plot(positions, vector1, marker='o', linestyle='-', label='Vector 1')
plt.plot(positions, vector2, marker='s', linestyle='--', label='Vector 2')

# Axis labels and title
plt.xlabel("Position (Index)")
plt.ylabel("Random Float Values")
plt.title("Comparison of Two Random Float Vectors")

# Legend and grid
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# Vector 1:
#  [ 9.4510653  38.01817722 48.1164339  39.55383838 44.86192603 29.60928295
#  45.6570138  14.42003188  0.99487979 16.06330859 41.75818011  7.44265236
#  27.08272111 41.39625053 45.06098959]
#
# Vector 2:
#  [29.43397206 35.79661105 42.50754131  5.86512181 48.70973706 32.66244583
#   0.26028834 17.27775828 30.98348202 10.58367826  2.6514071  19.35376131
#  35.47779404  3.30443073 40.50121651]
